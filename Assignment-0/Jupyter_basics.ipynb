# %% [markdown]
# <a href="https://colab.research.google.com/github/Vigneshthanga/258-Deep-Learning/blob/master/Assignment-0/Jupyter_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #HomeWork 1

# %% [markdown]
# ##0. Useful Magic Lines at the top of all cells

# %%
#To plot the graph in the output cell and save it with notebook
# %matplotlib inline

#To reload all modules before executing a new line
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ##1. Following is the first code cell

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# ##2. Loading a cat image from Google Drive

# %%
from PIL import Image
from google.colab import drive
drive.mount('/content/gdrive')
Image.open('/content/gdrive/My Drive/Colab Notebooks/61vEwCfFwvL.jpg')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x800 at 0x7F74E5D642E8>

# %% [markdown]
# ##3.Some useful Markdowns

# %% [markdown]
# __Bold Text__

# %% [markdown]
# `Inline Text`

# %% [markdown]
# _Italics text_

# %% [markdown]
# \>BlockQuote

# %% [markdown]
# [Github Homework link](https://github.com/Vigneshthanga/258-Deep-Learning)

# %% [markdown]
# ##4. Ploting with Matplotlib

# %%
import matplotlib.pyplot as plt
a = 1
b = 2
c = 4
d = 8
plt.plot([a,b,c,d])
plt.show()

# %% [markdown]
# ##5. Some useful tips for fastai Functions

# %%
from fastai import *
from fastai.vision import *

#shows definition of function 
# ?ImageDataBunch

#docstring of function
doc(ImageDataBunch)

#source code of function
??ImageDataBunch

# %% [markdown]
# ##6. Average time Profiling for a piece of code

# %%
# %timeit [i+1 for i in range(10)]
# Out:
# 1000000 loops, best of 3: 728 ns per loop

# %% [markdown]
# ##7. Debuging using line magic

# %%
# %debug
a = 1
b = 'b'
print(b+a)
# Out:
# > <ipython-input-1-c3b7a5c73751>(3)<module>()
#       1 a = 1
#       2 b = 'b'
# ----> 3 print(b+a)
#
# ipdb> print b
# *** SyntaxError: Missing parentheses in call to 'print'. Did you mean print(b)?
# ipdb> print(b)
# b
# ipdb> print(a)
# 1
# --KeyboardInterrupt--
# --KeyboardInterrupt--
# ipdb> quit
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-8827b4cb5d15> in <module>()
#       2 a = 1
#       3 b = 'b'
# ----> 4 print(b+a)
#
# TypeError: must be str, not int
